# %% [markdown]
# <a href="https://colab.research.google.com/github/vdeleon27/Big-data/blob/main/Python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Big Data
#
# # pandas data frame

# %%
import pandas as pd
from google.colab import files

# %%
d_star_wars = pd.read_csv(filepath_or_buffer="https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv", sep=',')
d_star_wars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species
# 0     male  Tatooine   Human
# 1      NaN  Tatooine   Droid
# 2      NaN     Naboo   Droid
# 3     male  Tatooine   Human
# 4   female  Alderaan   Human
# ..     ...       ...     ...
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
# 86  female     Naboo   Human
#
# [87 rows x 10 columns]

# %%
#Mostrar todas las columas del dataframa
d_star_wars.columns
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'gender', 'homeworld', 'species'],
#       dtype='object')

# %% [markdown]
# ### 1) ¿Cómo eliminar columnas?

# %%
# Una columna
d_star_wars.drop(columns='name')
# Out:
#     height mass hair_color   skin_color eye_color birth_year  gender  \
# 0    172.0   77      blond         fair      blue      19BBY    male
# 1    167.0   75        NaN         gold    yellow     112BBY     NaN
# 2     96.0   32        NaN  white, blue       red      33BBY     NaN
# 3    202.0  136       none        white    yellow    41.9BBY    male
# 4    150.0   49      brown        light     brown      19BBY  female
# ..     ...  ...        ...          ...       ...        ...     ...
# 82     NaN  NaN      brown        light     hazel        NaN  female
# 83     NaN  NaN      brown        light     brown        NaN    male
# 84     NaN  NaN       none         none     black        NaN    none
# 85     NaN  NaN        NaN          NaN       NaN        NaN  female
# 86   165.0   45      brown        light     brown      46BBY  female
#
#    homeworld species
# 0   Tatooine   Human
# 1   Tatooine   Droid
# 2      Naboo   Droid
# 3   Tatooine   Human
# 4   Alderaan   Human
# ..       ...     ...
# 82       NaN   Human
# 83       NaN   Human
# 84       NaN   Droid
# 85       NaN     NaN
# 86     Naboo   Human
#
# [87 rows x 9 columns]

# %%
# Eliminar N columnas
d_star_wars.drop(columns=['name', 'height'])
# Out:
#    mass hair_color   skin_color eye_color birth_year  gender homeworld species
# 0    77      blond         fair      blue      19BBY    male  Tatooine   Human
# 1    75        NaN         gold    yellow     112BBY     NaN  Tatooine   Droid
# 2    32        NaN  white, blue       red      33BBY     NaN     Naboo   Droid
# 3   136       none        white    yellow    41.9BBY    male  Tatooine   Human
# 4    49      brown        light     brown      19BBY  female  Alderaan   Human
# ..  ...        ...          ...       ...        ...     ...       ...     ...
# 82  NaN      brown        light     hazel        NaN  female       NaN   Human
# 83  NaN      brown        light     brown        NaN    male       NaN   Human
# 84  NaN       none         none     black        NaN    none       NaN   Droid
# 85  NaN        NaN          NaN       NaN        NaN  female       NaN     NaN
# 86   45      brown        light     brown      46BBY  female     Naboo   Human
#
# [87 rows x 8 columns]

# %% [markdown]
# ### 2) ¿Cómo eliminar duplicados?

# %%
d_star_wars_2 = d_star_wars[['hair_color',	'skin_color']]

d_star_wars_2
# Out:
#    hair_color   skin_color
# 0       blond         fair
# 1         NaN         gold
# 2         NaN  white, blue
# 3        none        white
# 4       brown        light
# ..        ...          ...
# 82      brown        light
# 83      brown        light
# 84       none         none
# 85        NaN          NaN
# 86      brown        light
#
# [87 rows x 2 columns]

# %%
d_star_wars_3=d_star_wars_2.drop_duplicates()

d_star_wars_3
# Out:
#        hair_color           skin_color
# 0           blond                 fair
# 1             NaN                 gold
# 2             NaN          white, blue
# 3            none                white
# 4           brown                light
# 5     brown, grey                light
# 7             NaN           white, red
# 8           black                light
# 9   auburn, white                 fair
# 11   auburn, grey                 fair
# 12          brown                  NaN
# 13          brown                 fair
# 14            NaN                green
# 15            NaN     green-tan, brown
# 18          white                green
# 19           grey                 pale
# 20          black                 fair
# 21           none                metal
# 22           none                green
# 23          black                 dark
# 24           none                light
# 25           none         brown mottle
# 26         auburn                 fair
# 28          brown                brown
# 29           none                 grey
# 31           none        mottled green
# 33           none               orange
# 37          black           blue, grey
# 38           none            grey, red
# 41           none                  red
# 42           none                 pale
# 43           none                 blue
# 44           none           blue, grey
# 45           none          white, blue
# 46           none  grey, green, yellow
# 47           none                 dark
# 48          white                 pale
# 50          black                brown
# 60          black               yellow
# 63          white                 fair
# 64          black                  tan
# 66         blonde  fair, green, yellow
# 67           none                brown
# 71           none           grey, blue
# 72           none          silver, red
# 73           none          green, grey
# 75           none     red, blue, white
# 76           none         brown, white
# 84           none                 none
# 85            NaN                  NaN

# %%
d_star_wars_3.shape
# Out:
# (50, 2)

# %% [markdown]
# 2.b) ¿Cómo obtener los registros duplicados?

# %%
d_star_wars_2[d_star_wars_2.duplicated()]
# Out:
#    hair_color skin_color
# 6       brown      light
# 10      blond       fair
# 16      brown       fair
# 17      brown       fair
# 27      brown       fair
# 30      brown       fair
# 32      blond       fair
# 34       none       grey
# 35       none      green
# 36      brown       fair
# 39      black       dark
# 40      black       fair
# 49       none      green
# 51       none       dark
# 52       none       pale
# 53       none      white
# 54       none     orange
# 55       none       blue
# 56      black       dark
# 57      brown      light
# 58      brown       fair
# 59       none      green
# 61      black     yellow
# 62      brown      light
# 65      black        tan
# 68       none       grey
# 69       none       grey
# 70      white       fair
# 74       none       grey
# 77      brown      brown
# 78      brown      light
# 79       none       pale
# 80       none       grey
# 81      black       dark
# 82      brown      light
# 83      brown      light
# 86      brown      light

# %%
d_star_wars_2[d_star_wars_2.duplicated()].shape
# Out:
# (37, 2)

# %% [markdown]
# ### 3) ¿Cómo ordenar un data frame?

# %%
d_star_wars.sort_values('birth_year') # analizar los últimos valores...
# Out:
#               name  height mass hair_color skin_color eye_color birth_year  \
# 63           Dooku   193.0   80      white       fair     brown     102BBY
# 1            C-3PO   167.0   75        NaN       gold    yellow     112BBY
# 21           IG-88   200.0  140       none      metal       red      15BBY
# 0   Luke Skywalker   172.0   77      blond       fair      blue      19BBY
# 4      Leia Organa   150.0   49      brown      light     brown      19BBY
# ..             ...     ...  ...        ...        ...       ...        ...
# 81            Finn     NaN  NaN      black       dark      dark        NaN
# 82             Rey     NaN  NaN      brown      light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown      light     brown        NaN
# 84             BB8     NaN  NaN       none       none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN        NaN       NaN        NaN
#
#     gender homeworld species
# 63    male   Serenno   Human
# 1      NaN  Tatooine   Droid
# 21    none       NaN   Droid
# 0     male  Tatooine   Human
# 4   female  Alderaan   Human
# ..     ...       ...     ...
# 81    male       NaN   Human
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
#
# [87 rows x 10 columns]

# %%
# Orden descendente
d_star_wars.sort_values('birth_year', ascending=False)
# Out:
#                      name  height mass hair_color skin_color eye_color  \
# 30           Qui-Gon Jinn   193.0   89      brown       fair      blue
# 48           Ki-Adi-Mundi   198.0   82      white       pale    yellow
# 32          Finis Valorum   170.0  NaN      blond       fair      blue
# 28  Wicket Systri Warrick    88.0   20      brown      brown     brown
# 18                   Yoda    66.0   17      white      green     brown
# ..                    ...     ...  ...        ...        ...       ...
# 81                   Finn     NaN  NaN      black       dark      dark
# 82                    Rey     NaN  NaN      brown      light     hazel
# 83            Poe Dameron     NaN  NaN      brown      light     brown
# 84                    BB8     NaN  NaN       none       none     black
# 85         Captain Phasma     NaN  NaN        NaN        NaN       NaN
#
#    birth_year  gender  homeworld         species
# 30      92BBY    male        NaN           Human
# 48      92BBY    male      Cerea          Cerean
# 32      91BBY    male  Coruscant           Human
# 28       8BBY    male      Endor            Ewok
# 18     896BBY    male        NaN  Yoda's species
# ..        ...     ...        ...             ...
# 81        NaN    male        NaN           Human
# 82        NaN  female        NaN           Human
# 83        NaN    male        NaN           Human
# 84        NaN    none        NaN           Droid
# 85        NaN  female        NaN             NaN
#
# [87 rows x 10 columns]

# %%
from google.colab.data_table import DataTable

# Ordenar por dos columnas
DataTable(d_star_wars.sort_values(['species', 'birth_year']))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>71</th>
#       <td>Ratts Tyerell</td>
#       <td>79.0</td>
#       <td>15</td>
#       <td>none</td>
#       <td>grey, blue</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>male</td>
#       <td>Aleen Minor</td>
#       <td>Aleena</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>Dexter Jettster</td>
#       <td>198.0</td>
#       <td>102</td>
#       <td>none</td>
#       <td>brown</td>
#       <td>yellow</td>
#       <td>NaN</td>
#       <td>male</td>
#       <td>Ojom</td>
#       <td>Besalisk</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Ki-Adi-Mundi</td>
#       <td>198.0</td>
#       <td>82</td>
#       <td>white</td>
#       <td>pale</td>
#       <td>yellow</td>
#       <td>92BBY</td>
#       <td>male</td>
#       <td>Cerea</td>
#       <td>Cerean</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>Mas Amedda</td>
#       <td>196.0</td>
#       <td>NaN</td>
#       <td>none</td>
#       <td>blue</td>
#       <td>blue</td>
#       <td>NaN</td>
#       <td>male</td>
#       <td>Champala</td>
#       <td>Chagrian</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Zam Wesell</td>
#       <td>168.0</td>
#       <td>55</td>
#       <td>blonde</td>
#       <td>fair, green, yellow</td>
#       <td>yellow</td>
#       <td>NaN</td>
#       <td>female</td>
#       <td>Zolan</td>
#       <td>Clawdite</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Quarsh Panaka</td>
#       <td>183.0</td>
#       <td>NaN</td>
#       <td>black</td>
#       <td>dark</td>
#       <td>brown</td>
#       <td>62BBY</td>
#       <td>male</td>
#       <td>Naboo</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Ric Olié</td>
#       <td>183.0</td>
#       <td>NaN</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>NaN</td>
#       <td>male</td>
#       <td>Naboo</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>R4-P17</td>
#       <td>96.0</td>
#       <td>NaN</td>
#       <td>none</td>
#       <td>silver, red</td>
#       <td>red, blue</td>
#       <td>NaN</td>
#       <td>female</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>Sly Moore</td>
#       <td>178.0</td>
#       <td>48</td>
#       <td>none</td>
#       <td>pale</td>
#       <td>white</td>
#       <td>NaN</td>
#       <td>female</td>
#       <td>Umbara</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>Captain Phasma</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>female</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>87 rows × 10 columns</p>
# </div>

# %%
# Emprolijar para chequear
d_sw_ordenado=d_star_wars.sort_values(['species', 'birth_year'])

# %%
# Comprobamos que están ordenados
d_sw_ordenado=d_sw_ordenado[['species', 'birth_year']]

DataTable(d_sw_ordenado)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>birth_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>71</th>
#       <td>Aleena</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>Besalisk</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Cerean</td>
#       <td>92BBY</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>Chagrian</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Clawdite</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>NaN</td>
#       <td>62BBY</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>87 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 4) ¿Cómo crear una variable en un dataframe?

# %%
d_star_wars['nueva_variable']=999

d_star_wars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species  nueva_variable
# 0     male  Tatooine   Human             999
# 1      NaN  Tatooine   Droid             999
# 2      NaN     Naboo   Droid             999
# 3     male  Tatooine   Human             999
# 4   female  Alderaan   Human             999
# ..     ...       ...     ...             ...
# 82  female       NaN   Human             999
# 83    male       NaN   Human             999
# 84    none       NaN   Droid             999
# 85  female       NaN     NaN             999
# 86  female     Naboo   Human             999
#
# [87 rows x 11 columns]

# %%
# Pasando a metros la altura
d_star_wars['height_mts']=d_star_wars['height']/100

d_star_wars.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species  nueva_variable  height_mts
# 0    male  Tatooine   Human             999        1.72
# 1     NaN  Tatooine   Droid             999        1.67
# 2     NaN     Naboo   Droid             999        0.96
# 3    male  Tatooine   Human             999        2.02
# 4  female  Alderaan   Human             999        1.50

# %% [markdown]
# ### 5) ¿Cómo reordenar variables en un pandas data frame?

# %%
# Tomo las 3 priemras columnas (name, height, mass)
d_star_wars_4=d_star_wars.iloc[:, 0:3]
d_star_wars_4.columns
# Out:
# Index(['name', 'height', 'mass'], dtype='object')

# %%
# reorden
d_star_wars_5=d_star_wars_4[['mass', 'height', 'name']]

# %%
d_star_wars_5
# Out:
#    mass  height            name
# 0    77   172.0  Luke Skywalker
# 1    75   167.0           C-3PO
# 2    32    96.0           R2-D2
# 3   136   202.0     Darth Vader
# 4    49   150.0     Leia Organa
# ..  ...     ...             ...
# 82  NaN     NaN             Rey
# 83  NaN     NaN     Poe Dameron
# 84  NaN     NaN             BB8
# 85  NaN     NaN  Captain Phasma
# 86   45   165.0   Padmé Amidala
#
# [87 rows x 3 columns]

# %% [markdown]
# ### 6) ¿Cómo renombrar variables?

# %%
d_star_wars_5.head()
# Out:
#   mass  height            name
# 0   77   172.0  Luke Skywalker
# 1   75   167.0           C-3PO
# 2   32    96.0           R2-D2
# 3  136   202.0     Darth Vader
# 4   49   150.0     Leia Organa

# %%
d_star_wars_5.rename(columns={'mass':'peso', 'height':'altura', 'name':'nombre'}).head()
# Out:
#   peso  altura          nombre
# 0   77   172.0  Luke Skywalker
# 1   75   167.0           C-3PO
# 2   32    96.0           R2-D2
# 3  136   202.0     Darth Vader
# 4   49   150.0     Leia Organa

# %%
# Aplicar función a todas las columnas. Todo a minúscula o mayúscula

d_star_wars_5.rename(str.upper, axis="columns").head()
# Out:
#   MASS  HEIGHT            NAME
# 0   77   172.0  Luke Skywalker
# 1   75   167.0           C-3PO
# 2   32    96.0           R2-D2
# 3  136   202.0     Darth Vader
# 4   49   150.0     Leia Organa

# %% [markdown]
# Eliminar espacios de las columnas

# %%
d_star_wars_6=d_star_wars_5.rename(columns={'mass':'peso del personaje', 'height':'altura del personaje'})
d_star_wars_6.head()
# Out:
#   peso del personaje  altura del personaje            name
# 0                 77                 172.0  Luke Skywalker
# 1                 75                 167.0           C-3PO
# 2                 32                  96.0           R2-D2
# 3                136                 202.0     Darth Vader
# 4                 49                 150.0     Leia Organa

# %%
d_star_wars_6.columns = d_star_wars_6.columns.str.replace(' ', '_')

d_star_wars_6.head()
# Out:
#   peso_del_personaje  altura_del_personaje            name
# 0                 77                 172.0  Luke Skywalker
# 1                 75                 167.0           C-3PO
# 2                 32                  96.0           R2-D2
# 3                136                 202.0     Darth Vader
# 4                 49                 150.0     Leia Organa

# %% [markdown]
# ### 7)  ¿Cómo filtrar datos con pandas query?

# %%
d_star_wars.query(" height > 220 ")
# Out:
#             name  height mass hair_color skin_color eye_color birth_year  \
# 12     Chewbacca   228.0  112      brown        NaN      blue     200BBY
# 34  Roos Tarpals   224.0   82       none       grey    orange        NaN
# 53   Yarael Poof   264.0  NaN       none      white    yellow        NaN
# 68       Lama Su   229.0   88       none       grey     black        NaN
# 77       Tarfful   234.0  136      brown      brown      blue        NaN
#
#    gender homeworld   species  nueva_variable  height_mts
# 12   male  Kashyyyk   Wookiee             999        2.28
# 34   male     Naboo    Gungan             999        2.24
# 53   male   Quermia  Quermian             999        2.64
# 68   male    Kamino  Kaminoan             999        2.29
# 77   male  Kashyyyk   Wookiee             999        2.34

# %%
# AND
d_star_wars.query(" height > 220 and hair_color == 'brown' ")
# Out:
#          name  height mass hair_color skin_color eye_color birth_year gender  \
# 12  Chewbacca   228.0  112      brown        NaN      blue     200BBY   male
# 77    Tarfful   234.0  136      brown      brown      blue        NaN   male
#
#    homeworld  species  nueva_variable  height_mts
# 12  Kashyyyk  Wookiee             999        2.28
# 77  Kashyyyk  Wookiee             999        2.34

# %%
# OR, filtrar extremos
d_star_wars.query("height < 150 or height > 220 ")
# Out:
#                      name  height mass hair_color   skin_color  eye_color  \
# 2                   R2-D2    96.0   32        NaN  white, blue        red
# 7                   R5-D4    97.0   32        NaN   white, red        red
# 12              Chewbacca   228.0  112      brown          NaN       blue
# 18                   Yoda    66.0   17      white        green      brown
# 28  Wicket Systri Warrick    88.0   20      brown        brown      brown
# 34           Roos Tarpals   224.0   82       none         grey     orange
# 37                  Watto   137.0  NaN      black   blue, grey     yellow
# 38                Sebulba   112.0   40       none    grey, red     orange
# 44               Dud Bolt    94.0   45       none   blue, grey     yellow
# 45                Gasgano   122.0  NaN       none  white, blue      black
# 53            Yarael Poof   264.0  NaN       none        white     yellow
# 68                Lama Su   229.0   88       none         grey      black
# 71          Ratts Tyerell    79.0   15       none   grey, blue        NaN
# 72                 R4-P17    96.0  NaN       none  silver, red  red, blue
# 77                Tarfful   234.0  136      brown        brown       blue
#
#    birth_year  gender    homeworld         species  nueva_variable  height_mts
# 2       33BBY     NaN        Naboo           Droid             999        0.96
# 7         NaN     NaN     Tatooine           Droid             999        0.97
# 12     200BBY    male     Kashyyyk         Wookiee             999        2.28
# 18     896BBY    male          NaN  Yoda's species             999        0.66
# 28       8BBY    male        Endor            Ewok             999        0.88
# 34        NaN    male        Naboo          Gungan             999        2.24
# 37        NaN    male     Toydaria       Toydarian             999        1.37
# 38        NaN    male    Malastare             Dug             999        1.12
# 44        NaN    male      Vulpter      Vulptereen             999        0.94
# 45        NaN    male      Troiken           Xexto             999        1.22
# 53        NaN    male      Quermia        Quermian             999        2.64
# 68        NaN    male       Kamino        Kaminoan             999        2.29
# 71        NaN    male  Aleen Minor          Aleena             999        0.79
# 72        NaN  female          NaN             NaN             999        0.96
# 77        NaN    male     Kashyyyk         Wookiee             999        2.34

# %% [markdown]
# ### 8) Descripción estadística básica

# %%
#Instalamos funpymodeling para obtener estadística de los datos

# %%capture
# !pip install funpymodeling

# %%
#importamos la librería para poder utilizarla
from funpymodeling.exploratory import status, freq_tbl, profiling_num

# %%
# Análisis univariado var numérica
profiling_num(d_star_wars)
# Out:
#          variable        mean    std_dev  variation_coef   p_0.01  p_0.05  \
# 0          height  174.358025  34.770429         0.19942   76.400   96.00
# 1  nueva_variable  999.000000   0.000000         0.00000  999.000  999.00
# 2      height_mts    1.743580   0.347704         0.19942    0.764    0.96
#
#    p_0.25  p_0.5  p_0.75  p_0.95  p_0.99
# 0  167.00  180.0  191.00  224.00   240.0
# 1  999.00  999.0  999.00  999.00   999.0
# 2    1.67    1.8    1.91    2.24     2.4

# %%
profiling_num(d_star_wars['birth_year'])
# Out:
# Empty DataFrame
# Columns: [variable, mean, std_dev, variation_coef, p_0.01, p_0.05, p_0.25, p_0.5, p_0.75, p_0.95, p_0.99]
# Index: []

# %%
# Análisis univariado var categórica
freq_tbl(d_star_wars)
# Out:
#               name  frequency  percentage  cumulative_perc
# 0   Luke Skywalker          1    0.011494         0.011494
# 1       Mas Amedda          1    0.011494         0.022989
# 2            Dooku          1    0.011494         0.034483
# 3            Dormé          1    0.011494         0.045977
# 4    Barriss Offee          1    0.011494         0.057471
# ..             ...        ...         ...              ...
# 82    Arvel Crynyd          1    0.011494         0.954023
# 83      Mon Mothma          1    0.011494         0.965517
# 84          Ackbar          1    0.011494         0.977011
# 85           Lobot          1    0.011494         0.988506
# 86   Padmé Amidala          1    0.011494         1.000000
#
# [87 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#      mass  frequency  percentage  cumulative_perc
# 0      80          6    0.068966         0.101695
# 1      79          4    0.045977         0.169492
# 2      77          3    0.034483         0.220339
# 3      75          3    0.034483         0.271186
# 4      84          3    0.034483         0.322034
# 5      55          2    0.022989         0.355932
# 6      45          2    0.022989         0.389831
# 7      50          2    0.022989         0.423729
# 8      82          2    0.022989         0.457627
# 9      48          2    0.022989         0.491525
# 10    136          2    0.022989         0.525424
# 11     32          2    0.022989         0.559322
# 12     88          1    0.011494         0.576271
# 13    102          1    0.011494         0.593220
# 14     66          1    0.011494         0.610169
# 15     85          1    0.011494         0.627119
# 16     15          1    0.011494         0.644068
# 17     87          1    0.011494         0.661017
# 18     65          1    0.011494         0.677966
# 19     57          1    0.011494         0.694915
# 20     40          1    0.011494         0.711864
# 21   56.2          1    0.011494         0.728814
# 22     68          1    0.011494         0.745763
# 23     90          1    0.011494         0.762712
# 24     89          1    0.011494         0.779661
# 25     20          1    0.011494         0.796610
# 26     83          1    0.011494         0.813559
# 27    113          1    0.011494         0.830508
# 28    140          1    0.011494         0.847458
# 29   78.2          1    0.011494         0.864407
# 30     17          1    0.011494         0.881356
# 31    110          1    0.011494         0.898305
# 32  1,358          1    0.011494         0.915254
# 33     74          1    0.011494         0.932203
# 34    112          1    0.011494         0.949153
# 35    120          1    0.011494         0.966102
# 36     49          1    0.011494         0.983051
# 37    159          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#        hair_color  frequency  percentage  cumulative_perc
# 0            none         37    0.425287         0.456790
# 1           brown         18    0.206897         0.679012
# 2           black         13    0.149425         0.839506
# 3           white          4    0.045977         0.888889
# 4           blond          3    0.034483         0.925926
# 5     brown, grey          1    0.011494         0.938272
# 6   auburn, white          1    0.011494         0.950617
# 7    auburn, grey          1    0.011494         0.962963
# 8            grey          1    0.011494         0.975309
# 9          auburn          1    0.011494         0.987654
# 10         blonde          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#              skin_color  frequency  percentage  cumulative_perc
# 0                  fair         17    0.195402         0.200000
# 1                 light         11    0.126437         0.329412
# 2                 green          6    0.068966         0.400000
# 3                  grey          6    0.068966         0.470588
# 4                  dark          6    0.068966         0.541176
# 5                  pale          5    0.057471         0.600000
# 6                 brown          4    0.045977         0.647059
# 7                   tan          2    0.022989         0.670588
# 8                yellow          2    0.022989         0.694118
# 9                  blue          2    0.022989         0.717647
# 10           blue, grey          2    0.022989         0.741176
# 11               orange          2    0.022989         0.764706
# 12                white          2    0.022989         0.788235
# 13          white, blue          2    0.022989         0.811765
# 14                metal          1    0.011494         0.823529
# 15         brown, white          1    0.011494         0.835294
# 16     red, blue, white          1    0.011494         0.847059
# 17          green, grey          1    0.011494         0.858824
# 18          silver, red          1    0.011494         0.870588
# 19           grey, blue          1    0.011494         0.882353
# 20  fair, green, yellow          1    0.011494         0.894118
# 21         brown mottle          1    0.011494         0.905882
# 22  grey, green, yellow          1    0.011494         0.917647
# 23           white, red          1    0.011494         0.929412
# 24                  red          1    0.011494         0.941176
# 25            grey, red          1    0.011494         0.952941
# 26     green-tan, brown          1    0.011494         0.964706
# 27                 gold          1    0.011494         0.976471
# 28        mottled green          1    0.011494         0.988235
# 29                 none          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#         eye_color  frequency  percentage  cumulative_perc
# 0           brown         21    0.241379         0.250000
# 1            blue         19    0.218391         0.476190
# 2          yellow         11    0.126437         0.607143
# 3           black         10    0.114943         0.726190
# 4          orange          8    0.091954         0.821429
# 5             red          5    0.057471         0.880952
# 6           hazel          3    0.034483         0.916667
# 7       blue-gray          1    0.011494         0.928571
# 8            pink          1    0.011494         0.940476
# 9       red, blue          1    0.011494         0.952381
# 10           gold          1    0.011494         0.964286
# 11  green, yellow          1    0.011494         0.976190
# 12          white          1    0.011494         0.988095
# 13           dark          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#    birth_year  frequency  percentage  cumulative_perc
# 0       19BBY          2    0.022989         0.046512
# 1       72BBY          2    0.022989         0.093023
# 2       48BBY          2    0.022989         0.139535
# 3     41.9BBY          2    0.022989         0.186047
# 4       52BBY          2    0.022989         0.232558
# 5       82BBY          2    0.022989         0.279070
# 6       92BBY          2    0.022989         0.325581
# 7        8BBY          1    0.011494         0.348837
# 8       91BBY          1    0.011494         0.372093
# 9       62BBY          1    0.011494         0.395349
# 10      22BBY          1    0.011494         0.418605
# 11      54BBY          1    0.011494         0.441860
# 12      37BBY          1    0.011494         0.465116
# 13      58BBY          1    0.011494         0.488372
# 14      40BBY          1    0.011494         0.511628
# 15     102BBY          1    0.011494         0.534884
# 16      67BBY          1    0.011494         0.558140
# 17      66BBY          1    0.011494         0.581395
# 18      41BBY          1    0.011494         0.604651
# 19      53BBY          1    0.011494         0.627907
# 20      31BBY          1    0.011494         0.651163
# 21     112BBY          1    0.011494         0.674419
# 22      15BBY          1    0.011494         0.697674
# 23    31.5BBY          1    0.011494         0.720930
# 24     896BBY          1    0.011494         0.744186
# 25      21BBY          1    0.011494         0.767442
# 26     600BBY          1    0.011494         0.790698
# 27      44BBY          1    0.011494         0.813953
# 28      29BBY          1    0.011494         0.837209
# 29     200BBY          1    0.011494         0.860465
# 30      64BBY          1    0.011494         0.883721
# 31      57BBY          1    0.011494         0.906977
# 32      24BBY          1    0.011494         0.930233
# 33      47BBY          1    0.011494         0.953488
# 34      33BBY          1    0.011494         0.976744
# 35      46BBY          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#           gender  frequency  percentage  cumulative_perc
# 0           male         62    0.712644         0.738095
# 1         female         19    0.218391         0.964286
# 2           none          2    0.022989         0.988095
# 3  hermaphrodite          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#          homeworld  frequency  percentage  cumulative_perc
# 0            Naboo         11    0.126437         0.142857
# 1         Tatooine         10    0.114943         0.272727
# 2         Alderaan          3    0.034483         0.311688
# 3           Kamino          3    0.034483         0.350649
# 4        Coruscant          3    0.034483         0.389610
# 5           Mirial          2    0.022989         0.415584
# 6         Kashyyyk          2    0.022989         0.441558
# 7         Corellia          2    0.022989         0.467532
# 8           Ryloth          2    0.022989         0.493506
# 9         Iridonia          1    0.011494         0.506494
# 10         Iktotch          1    0.011494         0.519481
# 11         Quermia          1    0.011494         0.532468
# 12           Dorin          1    0.011494         0.545455
# 13        Champala          1    0.011494         0.558442
# 14        Geonosis          1    0.011494         0.571429
# 15           Zolan          1    0.011494         0.584416
# 16         Serenno          1    0.011494         0.597403
# 17    Concord Dawn          1    0.011494         0.610390
# 18           Cerea          1    0.011494         0.623377
# 19            Ojom          1    0.011494         0.636364
# 20     Aleen Minor          1    0.011494         0.649351
# 21           Skako          1    0.011494         0.662338
# 22      Muunilinst          1    0.011494         0.675325
# 23           Shili          1    0.011494         0.688312
# 24           Kalee          1    0.011494         0.701299
# 25          Umbara          1    0.011494         0.714286
# 26     Glee Anselm          1    0.011494         0.727273
# 27         Vulpter          1    0.011494         0.740260
# 28      Haruun Kal          1    0.011494         0.753247
# 29            Tund          1    0.011494         0.766234
# 30         Stewjon          1    0.011494         0.779221
# 31          Eriadu          1    0.011494         0.792208
# 32           Rodia          1    0.011494         0.805195
# 33       Nal Hutta          1    0.011494         0.818182
# 34      Bestine IV          1    0.011494         0.831169
# 35       Trandosha          1    0.011494         0.844156
# 36         Socorro          1    0.011494         0.857143
# 37          Bespin          1    0.011494         0.870130
# 38        Mon Cala          1    0.011494         0.883117
# 39       Chandrila          1    0.011494         0.896104
# 40           Endor          1    0.011494         0.909091
# 41         Sullust          1    0.011494         0.922078
# 42  Cato Neimoidia          1    0.011494         0.935065
# 43        Toydaria          1    0.011494         0.948052
# 44       Malastare          1    0.011494         0.961039
# 45        Dathomir          1    0.011494         0.974026
# 46         Troiken          1    0.011494         0.987013
# 47          Utapau          1    0.011494         1.000000
#
# ----------------------------------------------------------------
#
#            species  frequency  percentage  cumulative_perc
# 0            Human         35    0.402299         0.426829
# 1            Droid          5    0.057471         0.487805
# 2           Gungan          3    0.034483         0.524390
# 3         Mirialan          2    0.022989         0.548780
# 4          Wookiee          2    0.022989         0.573171
# 5          Twi'lek          2    0.022989         0.597561
# 6         Kaminoan          2    0.022989         0.621951
# 7           Zabrak          2    0.022989         0.646341
# 8         Quermian          1    0.011494         0.658537
# 9          Kel Dor          1    0.011494         0.670732
# 10        Chagrian          1    0.011494         0.682927
# 11       Geonosian          1    0.011494         0.695122
# 12        Clawdite          1    0.011494         0.707317
# 13      Tholothian          1    0.011494         0.719512
# 14        Besalisk          1    0.011494         0.731707
# 15          Aleena          1    0.011494         0.743902
# 16         Skakoan          1    0.011494         0.756098
# 17            Muun          1    0.011494         0.768293
# 18         Togruta          1    0.011494         0.780488
# 19         Kaleesh          1    0.011494         0.792683
# 20        Iktotchi          1    0.011494         0.804878
# 21           Toong          1    0.011494         0.817073
# 22        Nautolan          1    0.011494         0.829268
# 23          Cerean          1    0.011494         0.841463
# 24           Xexto          1    0.011494         0.853659
# 25      Vulptereen          1    0.011494         0.865854
# 26             Dug          1    0.011494         0.878049
# 27       Toydarian          1    0.011494         0.890244
# 28       Neimodian          1    0.011494         0.902439
# 29       Sullustan          1    0.011494         0.914634
# 30            Ewok          1    0.011494         0.926829
# 31    Mon Calamari          1    0.011494         0.939024
# 32      Trandoshan          1    0.011494         0.951220
# 33  Yoda's species          1    0.011494         0.963415
# 34            Hutt          1    0.011494         0.975610
# 35          Rodian          1    0.011494         0.987805
# 36          Pau'an          1    0.011494         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# ¿Cómo aplicar funciones de sumarización a cada columna?

# %%
d_star_wars['height'].max()
# Out:
# 264.0

# %%
d_star_wars['height'].mean()
# Out:
# 174.35802469135803

# %%
print("El promedio de altura es %s y el  de la altura en mts es: %s" % (str(d_star_wars['height'].mean()), str(d_star_wars['height_mts'].mean())))
# Out:
# El promedio de altura es 174.35802469135803 y el  de la altura en mts es: 1.7435802469135802

# %% [markdown]
# ### 9) ¿Cómo exportar un pandas dataframe a csv?
# (y directorio de trabajo)

# %%
d_star_wars_2.head()
# Out:
#   hair_color   skin_color
# 0      blond         fair
# 1        NaN         gold
# 2        NaN  white, blue
# 3       none        white
# 4      brown        light

# %%
#Creamos un archivo csv desde un dataframa
d_star_wars_2.to_csv('starwars_colab.csv',  sep=',', index=False)

# %%
#Bajamos el archivo
files.download('starwars_colab.csv')

# %% [markdown]
# #Ejercicios
#
# Ejercicio 1: Basado en el dataframe d_star_wars agregar una columna nueva llamada BMI y calcular el indice de masa corporal (BMI) de cada personaje (mostrar nombre y BMI) [BMI = weight (kg) / height² (m²)]

# %%
#Antes de comenzar con los ejercicios volvemos a cargar los datos
d_star_wars = pd.read_csv(filepath_or_buffer="https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv", sep=',')

#Convertimos la columna peso (mass) a valores decimales
d_star_wars['mass'] = pd.to_numeric(d_star_wars['mass'], errors='coerce')

d_star_wars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN        NaN          NaN       NaN
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#    birth_year  gender homeworld species
# 0       19BBY    male  Tatooine   Human
# 1      112BBY     NaN  Tatooine   Droid
# 2       33BBY     NaN     Naboo   Droid
# 3     41.9BBY    male  Tatooine   Human
# 4       19BBY  female  Alderaan   Human
# ..        ...     ...       ...     ...
# 82        NaN  female       NaN   Human
# 83        NaN    male       NaN   Human
# 84        NaN    none       NaN   Droid
# 85        NaN  female       NaN     NaN
# 86      46BBY  female     Naboo   Human
#
# [87 rows x 10 columns]

# %%
#Ejercicio 1

# %% [markdown]
# Ejercicio 2: Mostrar nombre, altura y peso de todos los personajes ordenardos de mayor altura a menor altura

# %%
#Ejercicio 2
d_star_wars.sort_values('height', ascending=False)[['name', 'height', 'mass']]
# Out:
#               name  height   mass
# 53     Yarael Poof   264.0    NaN
# 77         Tarfful   234.0  136.0
# 68         Lama Su   229.0   88.0
# 12       Chewbacca   228.0  112.0
# 34    Roos Tarpals   224.0   82.0
# ..             ...     ...    ...
# 81            Finn     NaN    NaN
# 82             Rey     NaN    NaN
# 83     Poe Dameron     NaN    NaN
# 84             BB8     NaN    NaN
# 85  Captain Phasma     NaN    NaN
#
# [87 rows x 3 columns]

# %% [markdown]
# Ejercicio 3: Del campo hair_color reemplazar los valores nulos por 0 (cero)

# %%
#Ejercicio 3
d_star_wars['hair_color'] = d_star_wars['hair_color'].fillna(0)

# %% [markdown]
# Ejercicio 4: Listar los personajes femeninos de la raza humana.

# %%
#Ejercicio 4
d_star_wars.query("gender == 'female' and species == 'Human'")['name']
# Out:
# 4            Leia Organa
# 6     Beru Whitesun lars
# 26            Mon Mothma
# 40        Shmi Skywalker
# 57                 Cordé
# 62                 Dormé
# 70            Jocasta Nu
# 82                   Rey
# 86         Padmé Amidala
# Name: name, dtype: object

# %% [markdown]
# Ejercicio 5: listar todos los personajes que miden más de 2 metros.

# %%
#Ejercicio 5
d_star_wars.query("height > 200")['name']
# Out:
# 3      Darth Vader
# 12       Chewbacca
# 34    Roos Tarpals
# 35      Rugor Nass
# 53     Yarael Poof
# 68         Lama Su
# 69         Taun We
# 76        Grievous
# 77         Tarfful
# 80      Tion Medon
# Name: name, dtype: object

# %% [markdown]
# Ejercicio 6: calcular el peso promedio de los personajes por género. Redondear el peso a dos decimales.

# %%
#Ejercicio 6
d_star_wars.groupby('gender')['mass'].agg(lambda x: round(x.mean(), 2))
# Out:
# gender
# female            54.02
# hermaphrodite       NaN
# male              81.00
# none             140.00
# Name: mass, dtype: float64

# %% [markdown]
# Ejercicio 7: Calcular la altura máxima por cada especie

# %%
#Ejercicio 7
d_star_wars.groupby('species')['height'].max()
# Out:
# species
# Aleena             79.0
# Besalisk          198.0
# Cerean            198.0
# Chagrian          196.0
# Clawdite          168.0
# Droid             200.0
# Dug               112.0
# Ewok               88.0
# Geonosian         183.0
# Gungan            224.0
# Human             202.0
# Hutt              175.0
# Iktotchi          188.0
# Kaleesh           216.0
# Kaminoan          229.0
# Kel Dor           188.0
# Mirialan          170.0
# Mon Calamari      180.0
# Muun              191.0
# Nautolan          196.0
# Neimodian         191.0
# Pau'an            206.0
# Quermian          264.0
# Rodian            173.0
# Skakoan           193.0
# Sullustan         160.0
# Tholothian        184.0
# Togruta           178.0
# Toong             163.0
# Toydarian         137.0
# Trandoshan        190.0
# Twi'lek           180.0
# Vulptereen         94.0
# Wookiee           234.0
# Xexto             122.0
# Yoda's species     66.0
# Zabrak            175.0
# Name: height, dtype: float64

# %% [markdown]
# Ejercicio 8: Calcular la cantidad de personajes que contienen ojos de color rojo

# %%
#Ejercicio 8
d_star_wars.query("eye_color == 'red'").shape[0]
# Out:
# 5

# %% [markdown]
# Ejercicio 9: Mostrar los personajes que son del planeta Kamino y tienen piel de color gris

# %%
#Ejercicio 9
d_star_wars.query("homeworld == 'Kamino' and skin_color == 'grey'")['name']
# Out:
# 68    Lama Su
# 69    Taun We
# Name: name, dtype: object

# %% [markdown]
# Ejercicio 10: Mostrar los personajes que midan menos de 1 metro y que sean hombres

# %%
#Ejercicios 10

d_star_wars.query("height < 100 and gender == 'male'")['name']
# Out:
# 18                     Yoda
# 28    Wicket Systri Warrick
# 44                 Dud Bolt
# 71            Ratts Tyerell
# Name: name, dtype: object
